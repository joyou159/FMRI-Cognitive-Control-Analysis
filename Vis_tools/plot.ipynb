# %%
from graph import *

# %% [markdown]
# # Hardcoded Stats (After t-test)

# %% [markdown]
# After conducting the group analysis, we came up with 6 different Regions, which might be
# involved in the cognitive task of interest. These regions show high statistical significance for
# one task over the other. To conclude which task is the more significant, we would take a mask
# of specific size, in our case 5mm. Then, extract the average z-stats for each cope of the three.
# After that, we would apply a t-test to know which one of two task contribute the most. we get per region (mean, p-value).
# > Note: These values are computed using t.test() function in **R**

# %%
#------------------------------------ Cluster 1 ----------------------------------------------------
cluster1_mean = [ 2.264986, 1.572046, 0.737442] # [cong, incong, incong-cong] respectively
cluster1_significance = [ 5.704e-10, 1.294e-08, 0.000132]
#------------------------------------ Cluster 2 ----------------------------------------------------
cluster2_mean = [ 2.12427, 1.426941, 0.7225703]
cluster2_significance = [ 9.115e-09, 8.536e-08, 0.0001835]
#------------------------------------ Cluster 3 ----------------------------------------------------
cluster3_mean = [ 2.338692, 1.587225, 0.7989398] 
cluster3_significance = [ 1.801e-07, 1.281e-05, 4.939e-06]
#------------------------------------ Cluster 4 ----------------------------------------------------
cluster4_mean = [ 3.213907, 2.580819, 0.6779999]
cluster4_significance = [ 5.086e-10, 3.96e-09, 0.0001169]
#------------------------------------ Cluster 5 ----------------------------------------------------
cluster5_mean = [ 3.78052, 3.069232, 0.771117] 
cluster5_significance = [ 1.195e-13, 9.967e-12, 3.717e-07]
#------------------------------------ Cluster 6 ----------------------------------------------------
cluster6_mean = [ 2.814246, 2.001285, 0.8256334] 
cluster6_significance = [ 1.327e-09, 2.989e-07, 2.247e-06]
#---------------------------------------------------------------------------------------------------

# %%
plot_results(cluster1_mean, cluster1_significance, "Region 1")

# %%
plot_results(cluster2_mean, cluster2_significance, "Region 2")

# %%
plot_results(cluster3_mean, cluster3_significance, "Region 3")

# %%
plot_results(cluster4_mean, cluster4_significance, "Region 4")

# %%
plot_results(cluster5_mean, cluster5_significance, "Region 5")

# %%
plot_results(cluster6_mean, cluster6_significance, "Region 6")
